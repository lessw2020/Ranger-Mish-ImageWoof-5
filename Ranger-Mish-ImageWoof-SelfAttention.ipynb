# %%
#Below is the training settings used for ImageWoof 5 epoch, 128px.  You can kick off a run in the very next cell.
#There are some other sample runs showing how some of the settings were adjusted...if you find better settings please let us know!

# %%
# the --sa param controls self attention layer.  --sa 1 = yes, -- sa 0 = no self attention layer

# %%
# %run train.py --run 10 --woof 1 --size 128 --bs 64 --mixup 0 --epoch 5 --lr 4e-3 --gpu 0 \
                --opt ranger --mom .95 --sched_type flat_and_anneal --ann_start 0.72 --sa 1
# Out:
# Mish activation loaded...
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.972522</td>
#       <td>2.457129</td>
#       <td>0.244000</td>
#       <td>0.796000</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.697767</td>
#       <td>1.791513</td>
#       <td>0.418000</td>
#       <td>0.882000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.527037</td>
#       <td>1.422800</td>
#       <td>0.606000</td>
#       <td>0.940000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.389539</td>
#       <td>1.327014</td>
#       <td>0.646000</td>
#       <td>0.958000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.204918</td>
#       <td>1.120579</td>
#       <td>0.746000</td>
#       <td>0.980000</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='194', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/course-v3/nbs/dl1/train.py in <module>
#     163         log: Param("Log file name", str)='log',
#     164         sched_type: Param("LR schedule type", str)='one_cycle',
# --> 165         ann_start: Param("Mixup", float)=-1.0,
#     166         ):
#     167
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/script.py in call_parse(func)
#      38     if name == "__main__":
#      39         args = anno_parser(func).parse_args()
# ---> 40         func(**args.__dict__)
#      41     else: return func
#      42
#
# ~/course-v3/nbs/dl1/train.py in main(run, gpu, woof, lr, size, alpha, mom, eps, epochs, bs, mixup, opt, arch, sa, sym, dump, lrfinder, log, sched_type, ann_start)
#     168     acc = np.array(
#     169         [train(gpu,woof,lr,size,alpha,mom,eps,epochs,bs,mixup,opt,arch,sa,sym,dump,lrfinder,log,sched_type,ann_start)
# --> 170                 for i in range(run)])
#     171
#     172     print(acc)
#
# ~/course-v3/nbs/dl1/train.py in <listcomp>(.0)
#     168     acc = np.array(
#     169         [train(gpu,woof,lr,size,alpha,mom,eps,epochs,bs,mixup,opt,arch,sa,sym,dump,lrfinder,log,sched_type,ann_start)
# --> 170                 for i in range(run)])
#     171
#     172     print(acc)
#
# ~/course-v3/nbs/dl1/train.py in train(gpu, woof, lr, size, alpha, mom, eps, epochs, bs, mixup, opt, arch, sa, sym, dump, lrfinder, log, sched_type, ann_start)
#     138             learn.fit_one_cycle(epochs, lr, div_factor=10, pct_start=0.3)
#     139         elif sched_type == 'flat_and_anneal':
# --> 140             fit_with_annealing(learn, epochs, lr, ann_start)
#     141
#     142     return learn.recorder.metrics[-1][0]
#
# ~/course-v3/nbs/dl1/train.py in fit_with_annealing(learn, num_epoch, lr, annealing_start)
#      59     sched = GeneralScheduler(learn, phases)
#      60     learn.callbacks.append(sched)
# ---> 61     learn.fit(num_epoch)
#      62
#      63 def train(
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     200         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 201         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     202
#     203     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     100             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     101                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 102                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     103                 if cb_handler.on_batch_end(loss): break
#     104
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      34         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      35         if not skip_bwd:                     loss.backward()
# ---> 36         if not cb_handler.on_backward_end(): opt.step(float(loss))
#      37         if not cb_handler.on_step_end():     opt.zero_grad()
#      38
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/callback.py in on_backward_end(self)
#     295     def on_backward_end(self)->Any:
#     296         "Handle end of gradient calculation."
# --> 297         self('backward_end', call_mets=False)
#     298         return self.state_dict['skip_step']
#     299
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/callback.py in __call__(self, cb_name, call_mets, **kwargs)
#     249         if call_mets:
#     250             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# --> 251         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#     252
#     253     def set_dl(self, dl:DataLoader):
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/callback.py in _call_and_update(self, cb, cb_name, **kwargs)
#     239     def _call_and_update(self, cb, cb_name, **kwargs)->None:
#     240         "Call `cb_name` on `cb` and update the inner state."
# --> 241         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#     242         for k,v in new.items():
#     243             if k not in self.state_dict:
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/callbacks/fp16.py in on_backward_end(self, **kwargs)
#      98     def on_backward_end(self, **kwargs:Any)->None:
#      99         "Convert the gradients back to FP32 and divide them by the scale."
# --> 100         if self.dynamic and grad_overflow(self.model_params) and self.loss_scale > 1:
#     101             self.loss_scale /= 2
#     102             self.noskip = 0
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/callbacks/fp16.py in grad_overflow(param_group)
#      58         for p in group:
#      59             if p.grad is not None:
# ---> 60                 s = float(p.grad.data.float().sum())
#      61                 if s == float('inf') or s == float('-inf') or s != s: return True
#      62     return False
#
# KeyboardInterrupt:

# %%
# %run train.py --run 10 --woof 1 --size 128 --bs 64 --mixup 0 --epoch 5 --lr 4e-3 --gpu 0 \
                --opt ranger --mom .95 --sched_type flat_and_anneal --ann_start 0.72 --sa 1
# Out:
# Mish activation loaded...
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.932612</td>
#       <td>2.228929</td>
#       <td>0.310000</td>
#       <td>0.818000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.685795</td>
#       <td>1.918816</td>
#       <td>0.396000</td>
#       <td>0.902000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.521976</td>
#       <td>1.398177</td>
#       <td>0.612000</td>
#       <td>0.954000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.395458</td>
#       <td>1.299284</td>
#       <td>0.664000</td>
#       <td>0.950000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.192819</td>
#       <td>1.147381</td>
#       <td>0.738000</td>
#       <td>0.978000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.949795</td>
#       <td>1.948550</td>
#       <td>0.376000</td>
#       <td>0.824000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.673605</td>
#       <td>1.880013</td>
#       <td>0.376000</td>
#       <td>0.902000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.518188</td>
#       <td>1.415712</td>
#       <td>0.626000</td>
#       <td>0.940000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.375898</td>
#       <td>1.296974</td>
#       <td>0.664000</td>
#       <td>0.954000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.192598</td>
#       <td>1.137415</td>
#       <td>0.758000</td>
#       <td>0.970000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.902918</td>
#       <td>2.186243</td>
#       <td>0.320000</td>
#       <td>0.826000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.663039</td>
#       <td>2.029019</td>
#       <td>0.386000</td>
#       <td>0.864000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.497419</td>
#       <td>1.397467</td>
#       <td>0.624000</td>
#       <td>0.932000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.337433</td>
#       <td>1.327863</td>
#       <td>0.658000</td>
#       <td>0.952000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.170554</td>
#       <td>1.127986</td>
#       <td>0.736000</td>
#       <td>0.970000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.922796</td>
#       <td>2.148304</td>
#       <td>0.322000</td>
#       <td>0.874000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.662266</td>
#       <td>1.643887</td>
#       <td>0.484000</td>
#       <td>0.916000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.518881</td>
#       <td>1.422440</td>
#       <td>0.578000</td>
#       <td>0.958000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.386698</td>
#       <td>1.311176</td>
#       <td>0.658000</td>
#       <td>0.944000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.192612</td>
#       <td>1.162676</td>
#       <td>0.738000</td>
#       <td>0.964000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.971801</td>
#       <td>1.997220</td>
#       <td>0.362000</td>
#       <td>0.844000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.659847</td>
#       <td>2.193531</td>
#       <td>0.358000</td>
#       <td>0.882000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.492444</td>
#       <td>1.382124</td>
#       <td>0.614000</td>
#       <td>0.948000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.393946</td>
#       <td>1.302290</td>
#       <td>0.678000</td>
#       <td>0.960000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.183272</td>
#       <td>1.094690</td>
#       <td>0.760000</td>
#       <td>0.980000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='194', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/course-v3/nbs/dl1/train.py in <module>
#     163         log: Param("Log file name", str)='log',
#     164         sched_type: Param("LR schedule type", str)='one_cycle',
# --> 165         ann_start: Param("Mixup", float)=-1.0,
#     166         ):
#     167
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/script.py in call_parse(func)
#      38     if name == "__main__":
#      39         args = anno_parser(func).parse_args()
# ---> 40         func(**args.__dict__)
#      41     else: return func
#      42
#
# ~/course-v3/nbs/dl1/train.py in main(run, gpu, woof, lr, size, alpha, mom, eps, epochs, bs, mixup, opt, arch, sa, sym, dump, lrfinder, log, sched_type, ann_start)
#     168     acc = np.array(
#     169         [train(gpu,woof,lr,size,alpha,mom,eps,epochs,bs,mixup,opt,arch,sa,sym,dump,lrfinder,log,sched_type,ann_start)
# --> 170                 for i in range(run)])
#     171
#     172     print(acc)
#
# ~/course-v3/nbs/dl1/train.py in <listcomp>(.0)
#     168     acc = np.array(
#     169         [train(gpu,woof,lr,size,alpha,mom,eps,epochs,bs,mixup,opt,arch,sa,sym,dump,lrfinder,log,sched_type,ann_start)
# --> 170                 for i in range(run)])
#     171
#     172     print(acc)
#
# ~/course-v3/nbs/dl1/train.py in train(gpu, woof, lr, size, alpha, mom, eps, epochs, bs, mixup, opt, arch, sa, sym, dump, lrfinder, log, sched_type, ann_start)
#     138             learn.fit_one_cycle(epochs, lr, div_factor=10, pct_start=0.3)
#     139         elif sched_type == 'flat_and_anneal':
# --> 140             fit_with_annealing(learn, epochs, lr, ann_start)
#     141
#     142     return learn.recorder.metrics[-1][0]
#
# ~/course-v3/nbs/dl1/train.py in fit_with_annealing(learn, num_epoch, lr, annealing_start)
#      59     sched = GeneralScheduler(learn, phases)
#      60     learn.callbacks.append(sched)
# ---> 61     learn.fit(num_epoch)
#      62
#      63 def train(
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     200         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 201         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     202
#     203     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     100             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     101                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 102                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     103                 if cb_handler.on_batch_end(loss): break
#     104
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      34         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      35         if not skip_bwd:                     loss.backward()
# ---> 36         if not cb_handler.on_backward_end(): opt.step(float(loss))
#      37         if not cb_handler.on_step_end():     opt.zero_grad()
#      38
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/callback.py in step(self, loss)
#      55                     for p in pg2['params']: p.data.mul_(1 - wd*lr)
#      56             self.set_val('weight_decay', listify(0, self._wd))
# ---> 57         self.opt.step(loss)
#      58
#      59     def zero_grad(self)->None:
#
# ~/course-v3/nbs/dl1/ranger.py in step(self, closure)
#     115                     p_data_fp32.add_(-step_size, exp_avg)
#     116
# --> 117                 p.data.copy_(p_data_fp32)
#     118
#     119
#
# KeyboardInterrupt:

# %%
#With Simple Self Attention
# %run train.py --run 10 --woof 1 --size 128 --bs 64 --mixup 0 --epoch 5 --lr 4e-3 --gpu 0 \
                --opt ranger --mom .95 --sched_type flat_and_anneal --ann_start 0.72 --sa 1
# Out:
# Mish activation loaded...
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.946799</td>
#       <td>1.947311</td>
#       <td>0.362000</td>
#       <td>0.868000</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.682001</td>
#       <td>1.749048</td>
#       <td>0.442000</td>
#       <td>0.892000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.518547</td>
#       <td>1.417988</td>
#       <td>0.626000</td>
#       <td>0.936000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.380798</td>
#       <td>1.474813</td>
#       <td>0.620000</td>
#       <td>0.942000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.188291</td>
#       <td>1.123776</td>
#       <td>0.742000</td>
#       <td>0.972000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.946457</td>
#       <td>1.856189</td>
#       <td>0.382000</td>
#       <td>0.876000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.677104</td>
#       <td>1.888882</td>
#       <td>0.454000</td>
#       <td>0.882000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.500547</td>
#       <td>1.350322</td>
#       <td>0.650000</td>
#       <td>0.938000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.372412</td>
#       <td>1.273237</td>
#       <td>0.672000</td>
#       <td>0.976000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.178719</td>
#       <td>1.108501</td>
#       <td>0.780000</td>
#       <td>0.970000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.966393</td>
#       <td>2.129322</td>
#       <td>0.304000</td>
#       <td>0.824000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.707176</td>
#       <td>2.364628</td>
#       <td>0.278000</td>
#       <td>0.834000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.532894</td>
#       <td>1.446705</td>
#       <td>0.602000</td>
#       <td>0.942000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.402636</td>
#       <td>1.338713</td>
#       <td>0.654000</td>
#       <td>0.956000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.212961</td>
#       <td>1.134179</td>
#       <td>0.756000</td>
#       <td>0.962000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.916631</td>
#       <td>2.219474</td>
#       <td>0.308000</td>
#       <td>0.802000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.658371</td>
#       <td>1.739664</td>
#       <td>0.462000</td>
#       <td>0.926000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.521851</td>
#       <td>1.417715</td>
#       <td>0.592000</td>
#       <td>0.952000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.363294</td>
#       <td>1.312847</td>
#       <td>0.658000</td>
#       <td>0.960000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.174500</td>
#       <td>1.120707</td>
#       <td>0.770000</td>
#       <td>0.966000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.952344</td>
#       <td>1.884750</td>
#       <td>0.388000</td>
#       <td>0.862000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.705976</td>
#       <td>1.872791</td>
#       <td>0.392000</td>
#       <td>0.890000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.544782</td>
#       <td>1.427999</td>
#       <td>0.614000</td>
#       <td>0.944000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.407173</td>
#       <td>1.336221</td>
#       <td>0.646000</td>
#       <td>0.948000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.207502</td>
#       <td>1.142904</td>
#       <td>0.732000</td>
#       <td>0.976000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.945605</td>
#       <td>1.884218</td>
#       <td>0.390000</td>
#       <td>0.862000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.676344</td>
#       <td>2.744247</td>
#       <td>0.298000</td>
#       <td>0.762000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.518040</td>
#       <td>1.359121</td>
#       <td>0.642000</td>
#       <td>0.954000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.386391</td>
#       <td>1.408686</td>
#       <td>0.642000</td>
#       <td>0.948000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.189712</td>
#       <td>1.110767</td>
#       <td>0.760000</td>
#       <td>0.972000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.011343</td>
#       <td>1.985189</td>
#       <td>0.314000</td>
#       <td>0.854000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.692605</td>
#       <td>1.758937</td>
#       <td>0.468000</td>
#       <td>0.876000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.540829</td>
#       <td>1.390221</td>
#       <td>0.614000</td>
#       <td>0.964000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.416820</td>
#       <td>1.302732</td>
#       <td>0.670000</td>
#       <td>0.956000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.224493</td>
#       <td>1.150016</td>
#       <td>0.742000</td>
#       <td>0.968000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.011236</td>
#       <td>2.234993</td>
#       <td>0.296000</td>
#       <td>0.814000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.711826</td>
#       <td>1.771205</td>
#       <td>0.462000</td>
#       <td>0.906000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.518360</td>
#       <td>1.417754</td>
#       <td>0.592000</td>
#       <td>0.948000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.379984</td>
#       <td>1.304519</td>
#       <td>0.616000</td>
#       <td>0.964000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.197178</td>
#       <td>1.141052</td>
#       <td>0.736000</td>
#       <td>0.970000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.985876</td>
#       <td>1.894163</td>
#       <td>0.382000</td>
#       <td>0.874000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.686649</td>
#       <td>1.713661</td>
#       <td>0.464000</td>
#       <td>0.902000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.519158</td>
#       <td>1.396013</td>
#       <td>0.628000</td>
#       <td>0.954000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.375370</td>
#       <td>1.316989</td>
#       <td>0.634000</td>
#       <td>0.964000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.199393</td>
#       <td>1.132048</td>
#       <td>0.736000</td>
#       <td>0.978000</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# lr: 0.004; eff_lr: 0.004; size: 128; alpha: 0.99; mom: 0.95; eps: 1e-06
# /home/ubuntu/.fastai/data/imagewoof
# 698  annealing start
# Using Ranger Optimizer...
# Using Ranger Optimizer...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.970608</td>
#       <td>2.200298</td>
#       <td>0.346000</td>
#       <td>0.852000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.726249</td>
#       <td>2.140721</td>
#       <td>0.362000</td>
#       <td>0.824000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.532609</td>
#       <td>1.526804</td>
#       <td>0.554000</td>
#       <td>0.916000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.400649</td>
#       <td>1.361515</td>
#       <td>0.648000</td>
#       <td>0.964000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.211543</td>
#       <td>1.133623</td>
#       <td>0.738000</td>
#       <td>0.968000</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# [0.742 0.78  0.756 0.77  0.732 0.76  0.742 0.736 0.736 0.738]
# 0.7492
# 0.015548628

# %%
#possible ideas to test.....
# %run train.py --run 5 --woof 1 --size 128 --bs 64 --mixup 0 --epoch 20 --lr 3e-3 --gpu 0 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.7

# %%
# %run train.py --run 5 --woof 1 --size 128 --bs 64 --mixup 0 --epoch 20 --lr 5e-3 --gpu 0 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.7

# %%
# %run train.py --run 5 --woof 1 --size 128 --bs 64 --mixup 0 --epoch 20 --lr 8e-3 --gpu 0 \
                --opt ranger --sched_type flat_and_anneal --ann_start 0.7

# %%
# %run train.py --run 2 --woof 1 --size 128 --bs 64 --mixup 0 --epoch 5 --lr 2e-3 --gpu 0 \
                --opt adam --mom .95 --alpha .98 --sched_type flat_and_anneal --ann_start 0.5

# %%
# %run train.py --run 2 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 80 --lr 8e-2 --gpu 0 \
                --opt Adams --mom .95 --alpha .98 --sched_type flat_and_anneal --ann_start 0.3
